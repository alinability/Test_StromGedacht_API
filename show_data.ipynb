# %%
from get_data import show_current_carbon_intensity
from get_data import show_forecast_carbon_intensity
from get_data import show_forecast_all

# %%
show_current_carbon_intensity(70178) # gibt dir den aktuellen Strommix aus.

# %%
show_forecast_carbon_intensity(70178) # Gibt einem den Strommix für 96 Stunden in der Vergangenheit bis 48 Stunden in der Zukunft aus
# Es gibt auch die Möglichkeit das nicht wie hier über Stunden sondern konkrete Daten abzufragen.

# %%
show_forecast_all(70178) # Der plot macht nicht wirlich sinn. Aber man kann sich die geplotteten Werte ausgeben lassen.
